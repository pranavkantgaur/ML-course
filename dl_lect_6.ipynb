# %% [markdown]
# <a href="https://colab.research.google.com/github/pranavkantgaur/ML-course/blob/main/dl_lect_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Objectives
# •	Reinforcement Learning : Key concepts, Applications, Algorithms : Q-Learning,  Deep Q Network (DQN) and  Policy Gradient.

# %% [markdown]
# ## Reinforcement learning

# %% [markdown]
# ![online-offline-rl.gif](data:image/gif;base64,...)

# %% [markdown]
# ![offline-rl.gif](data:image/gif;base64,...)

# %% [markdown]
# ## Fun applications with seious implications

# %% [markdown]
# ![cartpole.gif](data:image/gif;base64,...)

# %% [markdown]
# ![atari-1-rl.gif](data:image/gif;base64,...)

# %% [markdown]
# ![atari-2-rl.gif](data:image/gif;base64,...)

# %% [markdown]
# ![atari-2-after-rl.gif](data:image/gif;base64,...)

# %%
# https://rubenfiszel.github.io/posts/rl4j/2016-08-24-Reinforcement-Learning-and-DQN.html
